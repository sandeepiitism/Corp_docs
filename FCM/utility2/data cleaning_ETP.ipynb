# %% [markdown]
# ### Approach of Data cleaning

# %%
## Data cleaning code working well with sheet no.:0-4 as 'After '
## Data cleaning code working well with sheet no.:5-10 as 'After'

# %%
import pandas as pd
import numpy as np

data = pd.read_excel("fcm_data_2.xlsx", skiprows=2, sheet_name=10, usecols="A:K")
data = data[["Date", "Tank No.", "pH", "Cond ", "BOD", "COD ", "TOC", "Turb ", 
                    "Hardness"]]

# data.head()

# %%
data.head(10)
# Out:
#         Date        Tank No.   pH  Cond     BOD   COD     TOC  Turb  Hardness
# 0 2024-01-01  708 ( Before )  5.2   7.00  176.0  534.0  214.0  289.0      NaN
# 1        NaT           After  6.8   8.20   69.5  210.0   10.2  120.0      300
# 2        NaT  705 ( Before )  4.3   6.50   79.3  241.0   96.8  130.0      NaN
# 3        NaT           After  7.1   7.10   32.4   69.5   36.5   52.1      250
# 4 2024-01-02  708 ( Before )  5.1   3.52    NaN    NaN    NaN    NaN      NaN
# 5        NaT           After  7.6   4.90    NaN    NaN    NaN    NaN       75
# 6        NaT  705 ( Before )  6.7   3.10    NaN    NaN    NaN    NaN      NaN
# 7        NaT           After  7.2   5.10    NaN    NaN    NaN    NaN      125
# 8        NaT  708 ( Before )  3.4   5.00    NaN    NaN    NaN    NaN      NaN
# 9        NaT           After  7.1   5.18    NaN    NaN    NaN    NaN      100

# %%
## repeats dates

data['Date'].fillna(method='ffill', inplace=True)
data.head(10)
# Out:
#         Date        Tank No.   pH  Cond     BOD   COD     TOC  Turb  Hardness
# 0 2024-01-01  708 ( Before )  5.2   7.00  176.0  534.0  214.0  289.0      NaN
# 1 2024-01-01           After  6.8   8.20   69.5  210.0   10.2  120.0      300
# 2 2024-01-01  705 ( Before )  4.3   6.50   79.3  241.0   96.8  130.0      NaN
# 3 2024-01-01           After  7.1   7.10   32.4   69.5   36.5   52.1      250
# 4 2024-01-02  708 ( Before )  5.1   3.52    NaN    NaN    NaN    NaN      NaN
# 5 2024-01-02           After  7.6   4.90    NaN    NaN    NaN    NaN       75
# 6 2024-01-02  705 ( Before )  6.7   3.10    NaN    NaN    NaN    NaN      NaN
# 7 2024-01-02           After  7.2   5.10    NaN    NaN    NaN    NaN      125
# 8 2024-01-02  708 ( Before )  3.4   5.00    NaN    NaN    NaN    NaN      NaN
# 9 2024-01-02           After  7.1   5.18    NaN    NaN    NaN    NaN      100

# %%
data['Tank No.'] = data['Tank No.'].replace('After ', np.nan)
data.head()
# Out:
#         Date        Tank No.   pH  Cond     BOD   COD     TOC  Turb  Hardness
# 0 2024-01-01  708 ( Before )  5.2   7.00  176.0  534.0  214.0  289.0      NaN
# 1 2024-01-01             NaN  6.8   8.20   69.5  210.0   10.2  120.0      300
# 2 2024-01-01  705 ( Before )  4.3   6.50   79.3  241.0   96.8  130.0      NaN
# 3 2024-01-01             NaN  7.1   7.10   32.4   69.5   36.5   52.1      250
# 4 2024-01-02  708 ( Before )  5.1   3.52    NaN    NaN    NaN    NaN      NaN

# %%
# data['Tank No.'] = data['Tank No.'].str.replace(r'After(\s+\d+)?', str(np.nan), regex=True)
# data.head()

# %%
data['Tank No.'].fillna(method='ffill', inplace=True)
data.head(10)
# Out:
#         Date        Tank No.   pH  Cond     BOD   COD     TOC  Turb  Hardness
# 0 2024-01-01  708 ( Before )  5.2   7.00  176.0  534.0  214.0  289.0      NaN
# 1 2024-01-01           After  6.8   8.20   69.5  210.0   10.2  120.0      300
# 2 2024-01-01  705 ( Before )  4.3   6.50   79.3  241.0   96.8  130.0      NaN
# 3 2024-01-01           After  7.1   7.10   32.4   69.5   36.5   52.1      250
# 4 2024-01-02  708 ( Before )  5.1   3.52    NaN    NaN    NaN    NaN      NaN
# 5 2024-01-02           After  7.6   4.90    NaN    NaN    NaN    NaN       75
# 6 2024-01-02  705 ( Before )  6.7   3.10    NaN    NaN    NaN    NaN      NaN
# 7 2024-01-02           After  7.2   5.10    NaN    NaN    NaN    NaN      125
# 8 2024-01-02  708 ( Before )  3.4   5.00    NaN    NaN    NaN    NaN      NaN
# 9 2024-01-02           After  7.1   5.18    NaN    NaN    NaN    NaN      100

# %%
## Eliminate all hardness NaN rows

# %%
data = data.dropna(subset=['Hardness'])
data.head()
# Out:
#         Date      Tank No.   pH Cond    BOD   COD    TOC Turb  Hardness
# 1 2023-09-01  708 (Before)  7.2     5  27.3   71.5  28.6  24.3      100
# 3 2023-09-01  701 (Before)  7.3   3.9  48.2   61.5  36.5  23.2       75
# 5 2023-09-01  708 (Before)  7.2     6  31.4   68.1  41.6  21.5      125
# 7 2023-09-01  701 (Before)  7.1   9.1  56.9  173.0  69.3  21.9      250
# 9 2023-09-01  708 (Before)    8     5  15.9   45.2  19.2  18.5      150

# %%
data['Tank No.'] = data['Tank No.'].str.replace(r'\s*\(Before\)', '', regex=True)
data.head()
# Out:
#         Date Tank No.   pH Cond    BOD   COD    TOC Turb  Hardness
# 1 2023-09-01      708  7.2     5  27.3   71.5  28.6  24.3      100
# 3 2023-09-01      701  7.3   3.9  48.2   61.5  36.5  23.2       75
# 5 2023-09-01      708  7.2     6  31.4   68.1  41.6  21.5      125
# 7 2023-09-01      701  7.1   9.1  56.9  173.0  69.3  21.9      250
# 9 2023-09-01      708    8     5  15.9   45.2  19.2  18.5      150

# %%
# Removing "( Before )" from the "Tank No." column
data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')

data.head()
# Out:
# C:\Users\CHS9NA\AppData\Local\Temp/ipykernel_16460/3952665172.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')
#         Date Tank No.   pH Cond    BOD   COD    TOC Turb  Hardness
# 1 2023-09-01      708  7.2     5  27.3   71.5  28.6  24.3      100
# 3 2023-09-01      701  7.3   3.9  48.2   61.5  36.5  23.2       75
# 5 2023-09-01      708  7.2     6  31.4   68.1  41.6  21.5      125
# 7 2023-09-01      701  7.1   9.1  56.9  173.0  69.3  21.9      250
# 9 2023-09-01      708    8     5  15.9   45.2  19.2  18.5      150

# %% [markdown]
# ## Functions

# %%
import pandas as pd
import numpy as np

def clean_data():
    data = pd.read_excel("fcm_data_2.xlsx", skiprows=2, sheet_name=10, usecols="A:K")
    data = data[["Date", "Tank No.", "pH", "Cond ", "BOD", "COD ", "TOC", "Turb ", 
                    "Hardness"]]
    data['Date'].fillna(method='ffill', inplace=True)
    data['Tank No.'] = data['Tank No.'].replace('After', np.nan)
    data['Tank No.'].fillna(method='ffill', inplace=True)
    data = data.dropna(subset=['Hardness'])
    data['Tank No.'] = data['Tank No.'].str.replace(r'\s*\(Before\)', '', regex=True)
    data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')
    return data

clean_data()
# Out:
# C:\Users\CHS9NA\AppData\Local\Temp/ipykernel_16460/1804014831.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')
#           Date Tank No.   pH  Cond    BOD  COD    TOC  Turb  Hardness
# 1   2024-03-01      701  7.5   9.74  29.3  89.1  35.6   35.7     300+
# 3   2024-03-01      708  7.2  14.32  21.5  65.3  26.1   36.0     300+
# 5   2024-03-01      705  6.8   5.15  16.9  46.8  18.5   27.5      150
# 7   2024-03-01      701  7.3   4.33  26.5  43.9  28.4   19.3       75
# 9   2024-03-01      708  7.2   8.10  25.4  38.9  26.2   28.4      200
# ..         ...      ...  ...    ...   ...   ...   ...    ...      ...
# 253 2024-03-21      705  7.5   6.00  14.8  45.6  18.0   50.0       75
# 255 2024-03-21      708  7.3  18.40  65.2  80.5  74.6   96.5      200
# 257 2024-03-21      701  7.6   3.00  27.2  84.4  34.6   24.7      150
# ...

# %%
import pandas as pd
import numpy as np

def clean_data(sheet_name):
    data = pd.read_excel("fcm_data_2.xlsx", skiprows=2, sheet_name=sheet_name, usecols="A:K")
    data = data[["Date", "Tank No.", "pH", "Cond ", "BOD", "COD ", "TOC", "Turb ", 
                    "Hardness"]]
    data['Date'].fillna(method='ffill', inplace=True)
    data['Tank No.'] = data['Tank No.'].replace('After ', np.nan)
    data['Tank No.'].fillna(method='ffill', inplace=True)
    data = data.dropna(subset=['Hardness'])
    data['Tank No.'] = data['Tank No.'].str.replace(r'\s*\(Before\)', '', regex=True)
    data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')
    return data


data_sheet_0 = clean_data(0)
data_sheet_1 = clean_data(1)
data_sheet_2 = clean_data(2)
data_sheet_3 = clean_data(3)
data_sheet_4 = clean_data(4)
# Out:
# C:\Users\CHS9NA\AppData\Local\Temp/ipykernel_16460/1153061116.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')

# %%
combined_data = pd.concat([data_sheet_0, data_sheet_1, data_sheet_2, data_sheet_3, data_sheet_4])

# Save the combined data to a CSV file
combined_data.to_csv('delete.csv', index=False)

# %%
import pandas as pd
import numpy as np

def clean_data(sheet_name):
    data = pd.read_excel("fcm_data_2.xlsx", skiprows=2, sheet_name=sheet_name, usecols="A:K")
    data = data[["Date", "Tank No.", "pH", "Cond ", "BOD", "COD ", "TOC", "Turb ", 
                    "Hardness"]]
    data['Date'].fillna(method='ffill', inplace=True)
    data['Tank No.'] = data['Tank No.'].replace(r'^After\s*$', np.nan, regex=True)
    data['Tank No.'].fillna(method='ffill', inplace=True)
    data = data.dropna(subset=['Hardness'])
    data['Tank No.'] = data['Tank No.'].str.replace(r'\s*\(Before\)', '', regex=True)
    data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')
    return data

data_sheet_0 = clean_data(0)
data_sheet_1 = clean_data(1)
data_sheet_2 = clean_data(2)
data_sheet_3 = clean_data(3)
data_sheet_4 = clean_data(4)
data_sheet_5 = clean_data(5)
data_sheet_6 = clean_data(6)
data_sheet_7 = clean_data(7)
data_sheet_8 = clean_data(8)
data_sheet_9 = clean_data(9)
data_sheet_10 = clean_data(10)
# Out:
# C:\Users\CHS9NA\AppData\Local\Temp/ipykernel_16460/351060087.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')

# %%
combined_data = pd.concat([data_sheet_0, data_sheet_1, data_sheet_2, data_sheet_3, data_sheet_4,
                          data_sheet_5, data_sheet_6, data_sheet_7, data_sheet_8, data_sheet_9, data_sheet_10])

# Save the combined data to a CSV file
combined_data.to_csv('cleaned_fcm.csv', index=False)

# %%
import pandas as pd
import numpy as np

def clean_data(sheet_name):
    data = pd.read_excel("fcm_data_2.xlsx", skiprows=2, sheet_name=sheet_name, usecols="A:K")
    data = data[["Date", "Tank No.", "pH", "Cond ", "BOD", "COD ", "TOC", "Turb ", 
                    "Hardness"]]
    data['Date'].fillna(method='ffill', inplace=True)
    data['Tank No.'] = data['Tank No.'].replace(r'^After\s*$', np.nan, regex=True)
    data['Tank No.'].fillna(method='ffill', inplace=True)
    data = data.dropna(subset=['Hardness'])
    data['Tank No.'] = data['Tank No.'].str.replace(r'\s*\(Before\)', '', regex=True)
    data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')
    # Convert 'Hardness' column to string type
    data['Hardness'] = data['Hardness'].astype(str)
    # Remove '+' sign from 'Hardness' values
    data['Hardness'] = data['Hardness'].str.replace('+', '')
    return data


data_sheet_0 = clean_data(0)
data_sheet_1 = clean_data(1)
data_sheet_2 = clean_data(2)
data_sheet_3 = clean_data(3)
data_sheet_4 = clean_data(4)
data_sheet_5 = clean_data(5)
data_sheet_6 = clean_data(6)
data_sheet_7 = clean_data(7)
data_sheet_8 = clean_data(8)
data_sheet_9 = clean_data(9)
data_sheet_10 = clean_data(10)

combined_data = pd.concat([data_sheet_0, data_sheet_1, data_sheet_2, data_sheet_3, data_sheet_4,
                          data_sheet_5, data_sheet_6, data_sheet_7, data_sheet_8, data_sheet_9, data_sheet_10])

# Save the combined data to a CSV file
combined_data.to_csv('cleaned_fcm_1.csv', index=False)
# Out:
# C:\Users\CHS9NA\AppData\Local\Temp/ipykernel_16460/4029272730.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')
# C:\Users\CHS9NA\AppData\Local\Temp/ipykernel_16460/4029272730.py:17: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Hardness'] = data['Hardness'].str.replace('+', '')

# %%
import pandas as pd
import numpy as np

def clean_data(sheet_name):
    data = pd.read_excel("fcm_data_2.xlsx", skiprows=2, sheet_name=sheet_name, usecols="A:K")
    data = data[["Date", "Tank No.", "pH", "Cond ", "BOD", "COD ", "TOC", "Turb ", 
                    "Hardness"]]
    data['Date'].fillna(method='ffill', inplace=True)
    data['Tank No.'] = data['Tank No.'].replace(r'^After\s*$', np.nan, regex=True)
    data['Tank No.'].fillna(method='ffill', inplace=True)
    data = data.dropna(subset=['Hardness'])
    data['Tank No.'] = data['Tank No.'].str.replace(r'\s*\(Before\)', '', regex=True)
    data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')
    data['Hardness'] = data['Hardness'].astype(str)
    data['Hardness'] = data['Hardness'].str.replace('+', '')
    return data[["Date", "Tank No.", "Hardness"]]

clean_data(0)
# Out:
# C:\Users\CHS9NA\AppData\Local\Temp/ipykernel_16460/2959650468.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')
# C:\Users\CHS9NA\AppData\Local\Temp/ipykernel_16460/2959650468.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Hardness'] = data['Hardness'].str.replace('+', '')
#           Date Tank No. Hardness
# 1   2023-05-02      708    150.0
# 3   2023-05-02      701    100.0
# 5   2023-05-02      708    200.0
# 7   2023-05-02      705    175.0
# 9   2023-05-02      701    150.0
# ..         ...      ...      ...
# 431 2023-05-31      708     75.0
# 433 2023-05-31      701     50.0
# 435 2023-05-31      708     50.0
# 437 2023-05-31      701    125.0
# 439 2023-05-31      705    150.0
#
# ...

# %%
import pandas as pd
from prophet import Prophet

def create_prophet_model(dataframe):
    dataframe = dataframe.rename(columns={'Date': 'ds', 'Hardness': 'y'})
    model = Prophet()
    model.fit(dataframe)
    return model


def forecast_hardness(model, forecast_date):
    future = pd.DataFrame({'ds': [forecast_date]})
    forecast = model.predict(future)
    return forecast['yhat'].iloc[0]


df = pd.DataFrame(clean_data(0))

model = create_prophet_model(df)
print(forecast_hardness(model, "2023-06-02"))


# forecast_date = '2023-06-01'  
# forecasted_hardness = forecast_hardness(model, forecast_date)
# print(f"Forecasted hardness for {forecast_date}: {forecasted_hardness}")
# Out:
# C:\Users\CHS9NA\AppData\Local\Temp/ipykernel_16460/739594481.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')
# C:\Users\CHS9NA\AppData\Local\Temp/ipykernel_16460/739594481.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Hardness'] = data['Hardness'].str.replace('+', '')
# 15:39:29 - cmdstanpy - INFO - Chain [1] start processing
# 15:39:29 - cmdstanpy - INFO - Chain [1] done processing
# 116.85468188118769

# %%
import pandas as pd
from prophet import Prophet
import numpy as np

def clean_data(sheet_name):
    data = pd.read_excel("fcm_data_2.xlsx", skiprows=2, sheet_name=sheet_name, usecols="A:K")
    data = data[["Date", "Tank No.", "pH", "Cond ", "BOD", "COD ", "TOC", "Turb ", 
                    "Hardness"]]
    data['Date'].fillna(method='ffill', inplace=True)
    data['Tank No.'] = data['Tank No.'].replace(r'^After\s*$', np.nan, regex=True)
    data['Tank No.'].fillna(method='ffill', inplace=True)
    data = data.dropna(subset=['Hardness'])
    data['Tank No.'] = data['Tank No.'].str.replace(r'\s*\(Before\)', '', regex=True)
    data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')
    data['Hardness'] = data['Hardness'].astype(str)
    data['Hardness'] = data['Hardness'].str.replace('+', '')
    return data[["Date", "Tank No.", "Hardness"]]

def create_prophet_model(dataframe):
    dataframe = dataframe.rename(columns={'Date': 'ds', 'Hardness': 'y'})
    if len(dataframe) < 2:
        raise ValueError("Dataframe has less than 2 non-NaN rows.")
    model = Prophet()
    model.fit(dataframe)
    return model

def forecast_hardness(model, forecast_date):
    future = pd.DataFrame({'ds': [forecast_date]})
    forecast = model.predict(future)
    return forecast['yhat'].iloc[0]

def group_tank(tank_no, forecast_date):
    tank_df = df[df['Tank No.'] == tank_no]
    if tank_df.empty:
        print("Tank number not found in the data.")
        return None
    if tank_df.isnull().values.any():
        raise ValueError("Tank data contains missing values.")
    try:
        model = create_prophet_model(tank_df)
    except ValueError as e:
        print(e)
        return None
    hardness_forecast = forecast_hardness(model, forecast_date)
    return hardness_forecast

df = pd.DataFrame(clean_data(0))

tank_no = input("Enter tank number: ")
forecast_date = "2023-06-02"

forecast = group_tank(tank_no, forecast_date)
if forecast is not None:
    print("Forecasted hardness for tank", tank_no, ":", forecast)
# Out:
# C:\Users\CHS9NA\AppData\Local\Temp/ipykernel_16460/839455424.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Tank No.'] = data['Tank No.'].str.replace(' \( Before \)', '')
# C:\Users\CHS9NA\AppData\Local\Temp/ipykernel_16460/839455424.py:16: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Hardness'] = data['Hardness'].str.replace('+', '')
# Enter tank number: 701
# 15:58:12 - cmdstanpy - INFO - Chain [1] start processing
# 15:58:12 - cmdstanpy - INFO - Chain [1] done processing
# Forecasted hardness for tank 701 : 98.73848048450334

# %%
import pandas as pd
from prophet import Prophet
import numpy as np

def clean_data():
    data = pd.read_csv("cleaned_fcm.csv")
    return data[["Date", "Tank No.", "Hardness"]]

def create_prophet_model(dataframe):
    dataframe = dataframe.rename(columns={'Date': 'ds', 'Hardness': 'y'})
    if len(dataframe) < 2:
        raise ValueError("Dataframe has less than 2 non-NaN rows.")
    model = Prophet()
    model.fit(dataframe)
    return model

def forecast_hardness(model, forecast_date):
    future = pd.DataFrame({'ds': [forecast_date]})
    forecast = model.predict(future)
    return forecast['yhat'].iloc[0], forecast_date

def group_tank(tank_no, forecast_date):
    tank_df = df[df['Tank No.'] == tank_no]
    if tank_df.empty:
        print("Tank number not found in the data.")
        return None, None
    if tank_df.isnull().values.any():
        raise ValueError("Tank data contains missing values.")
    try:
        model = create_prophet_model(tank_df)
    except ValueError as e:
        print(e)
        return None, None
    hardness_forecast, forecast_date = forecast_hardness(model, forecast_date)
    return hardness_forecast, forecast_date

df = pd.DataFrame(clean_data())

tank_no = int(input("Enter tank number: "))
forecast_date = input("Enter forecast date (YYYY-MM-DD): ")

forecast_value, forecast_date = group_tank(tank_no, forecast_date)
if forecast_value is not None:
    print("Forecasted hardness for tank", tank_no, "on", forecast_date, ":", forecast_value)
# Out:
# Enter tank number: 708
# Enter forecast date (YYYY-MM-DD): 2024-04-06
# 16:08:38 - cmdstanpy - INFO - Chain [1] start processing
# 16:08:38 - cmdstanpy - INFO - Chain [1] done processing
# Forecasted hardness for tank 708 on 2024-04-06 : 171.3584253699335

# %%
data = pd.read_csv("cleaned_fcm.csv")
data = data[["Date", "Tank No.", "Hardness"]]
data["Hardness"]
