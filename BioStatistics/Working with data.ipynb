# %%
import pandas as pd

# %%
df = pd.read_excel("Comorbid.xlsx")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Age Grade                                          Logistics  Temperature  \
# 0   77     B  Immediate Surgical intervention(then Ward / IC...         37.4
# 1   64     A                             Admit to Ward for Care         38.0
# 2   87     A                             Admit to Ward for Care         38.5
# 3   70     A                             Admit to Ward for Care         38.2
# 4   85     B                             Admit to Ward for Care         38.1
#
#   Pneumonia Hypertension DiabetesMellitus
# 0        No           No               No
# 1        No          Yes               No
# 2        No           No               No
# 3        No           No               No
# 4        No          Yes               No

# %%
df.tail()
# Out:
#      Age Grade               Logistics  Temperature Pneumonia Hypertension  \
# 592   54     A  Admit to Ward for Care         39.9        No           No
# 593   40     B  Admit to Ward for Care         39.0        No           No
# 594   18     A  Admit to Ward for Care         39.1        No           No
# 595   33     A  Admit to Ward for Care         38.9        No           No
# 596   24     B  Admit to Ward for Care         37.3        No          Yes
#
#     DiabetesMellitus
# 592               No
# 593               No
# 594               No
# 595               No
# 596               No

# %%
df.columns
# Out:
# Index(['Age', 'Grade', 'Logistics', 'Temperature', 'Pneumonia', 'Hypertension',
#        'DiabetesMellitus'],
#       dtype='object')

# %%
len(df)
# Out:
# 597

# %%
df.shape
# Out:
# (597, 7)

# %%
df.shape[0]
# Out:
# 597

# %%
df.shape[1]
# Out:
# 7

# %%
df.Temperature
# Out:
# 0      37.4
# 1      38.0
# 2      38.5
# 3      38.2
# 4      38.1
# 5      37.1
# 6      38.0
# 7      38.1
# 8      37.9
# 9      37.8
# 10     36.6
# 11     39.1
# 12     36.4
# 13     39.3
# 14     36.1
# 15     37.3
# 16     38.3
# 17     37.1
# 18     38.3
# 19     37.5
# 20     36.6
# 21     37.4
# 22     36.5
# 23     37.0
# 24     38.4
# 25     38.4
# 26     35.9
# 27     39.4
# 28     36.2
# 29     37.9
#        ...
# 567    39.3
# 568    36.2
# 569    37.5
# 570    38.6
# 571    39.2
# 572    37.3
# 573    39.8
# 574    37.7
# 575    39.1
# 576    39.7
# 577    37.7
# 578    36.2
# 579    38.8
# 580    37.9
# 581    36.8
# 582    38.9
# 583    37.1
# 584    36.8
# 585    39.5
# 586    35.9
# 587    38.7
# 588    39.4
# 589    36.0
# 590    37.9
# 591    38.0
# 592    39.9
# 593    39.0
# 594    39.1
# 595    38.9
# 596    37.3
# Name: Temperature, Length: 597, dtype: float64

# %%
df["Temperature"]
# Out:
# 0      37.4
# 1      38.0
# 2      38.5
# 3      38.2
# 4      38.1
# 5      37.1
# 6      38.0
# 7      38.1
# 8      37.9
# 9      37.8
# 10     36.6
# 11     39.1
# 12     36.4
# 13     39.3
# 14     36.1
# 15     37.3
# 16     38.3
# 17     37.1
# 18     38.3
# 19     37.5
# 20     36.6
# 21     37.4
# 22     36.5
# 23     37.0
# 24     38.4
# 25     38.4
# 26     35.9
# 27     39.4
# 28     36.2
# 29     37.9
#        ...
# 567    39.3
# 568    36.2
# 569    37.5
# 570    38.6
# 571    39.2
# 572    37.3
# 573    39.8
# 574    37.7
# 575    39.1
# 576    39.7
# 577    37.7
# 578    36.2
# 579    38.8
# 580    37.9
# 581    36.8
# 582    38.9
# 583    37.1
# 584    36.8
# 585    39.5
# 586    35.9
# 587    38.7
# 588    39.4
# 589    36.0
# 590    37.9
# 591    38.0
# 592    39.9
# 593    39.0
# 594    39.1
# 595    38.9
# 596    37.3
# Name: Temperature, Length: 597, dtype: float64

# %%
df.Grade
# Out:
# 0      B
# 1      A
# 2      A
# 3      A
# 4      B
# 5      B
# 6      B
# 7      A
# 8      A
# 9      A
# 10     A
# 11     B
# 12     B
# 13     B
# 14     B
# 15     A
# 16     B
# 17     B
# 18     A
# 19     B
# 20     A
# 21     A
# 22     A
# 23     A
# 24     B
# 25     A
# 26     B
# 27     A
# 28     A
# 29     A
#       ..
# 567    A
# 568    B
# 569    B
# 570    A
# 571    A
# 572    A
# 573    B
# 574    B
# 575    A
# 576    A
# 577    A
# 578    A
# 579    A
# 580    B
# 581    B
# 582    A
# 583    B
# 584    B
# 585    B
# 586    B
# 587    B
# 588    A
# 589    A
# 590    A
# 591    B
# 592    A
# 593    B
# 594    A
# 595    A
# 596    B
# Name: Grade, Length: 597, dtype: object

# %%
df[df.Grade == "A"]
# Out:
#      Age Grade                                          Logistics  \
# 1     64     A                             Admit to Ward for Care
# 2     87     A                             Admit to Ward for Care
# 3     70     A                             Admit to Ward for Care
# 7     29     A                             Admit to Ward for Care
# 8     73     A                             Admit to Ward for Care
# 9     68     A                             Admit to Ward for Care
# 10    54     A                        Admit to ICU / HCU for Care
# 15    82     A                             Admit to Ward for Care
# 18    22     A                             Admit to Ward for Care
# 20    53     A                             Admit to Ward for Care
# 21    40     A  Immediate Surgical intervention(then Ward / IC...
# 22    87     A                             Admit to Ward for Care
# 23    39     A                             Admit to Ward for Care
# ...

# %%
df[df.Temperature >= 39.5]
# Out:
#      Age Grade                                          Logistics  \
# 49    22     B                             Admit to Ward for Care
# 54    28     B                        Admit to ICU / HCU for Care
# 60    49     B  Immediate Surgical intervention(then Ward / IC...
# 67    38     B  Immediate Surgical intervention(then Ward / IC...
# 72    59     A                             Admit to Ward for Care
# 96    34     B                        Admit to ICU / HCU for Care
# 103   84     A  Immediate Surgical intervention(then Ward / IC...
# 113   63     A                             Admit to Ward for Care
# 118   26     A                        Admit to ICU / HCU for Care
# 121   66     B                             Admit to Ward for Care
# 126   59     A                             Admit to Ward for Care
# 129   65     A         Consultation only (leave in original ward)
# 142   63     B                             Admit to Ward for Care
# ...

# %%
df[(df.Grade == "A") & (df.Temperature >= 39.5)]
# Out:
#      Age Grade                                          Logistics  \
# 72    59     A                             Admit to Ward for Care
# 103   84     A  Immediate Surgical intervention(then Ward / IC...
# 113   63     A                             Admit to Ward for Care
# 118   26     A                        Admit to ICU / HCU for Care
# 126   59     A                             Admit to Ward for Care
# 129   65     A         Consultation only (leave in original ward)
# 162   54     A  Immediate Surgical intervention(then Ward / IC...
# 202   66     A  Immediate Surgical intervention(then Ward / IC...
# 204   57     A                             Admit to Ward for Care
# 234   32     A                             Admit to Ward for Care
# 236   69     A                             Admit to Ward for Care
# 265   24     A  Immediate Surgical intervention(then Ward / IC...
# 298   81     A                             Admit to Ward for Care
# ...

# %%
df[df.Grade != "A"]
# Out:
#      Age Grade                                          Logistics  \
# 0     77     B  Immediate Surgical intervention(then Ward / IC...
# 4     85     B                             Admit to Ward for Care
# 5     30     B  Immediate Surgical intervention(then Ward / IC...
# 6     60     B                             Admit to Ward for Care
# 11    74     B                             Admit to Ward for Care
# 12    47     B                             Admit to Ward for Care
# 13    88     B                        Admit to ICU / HCU for Care
# 14    39     B                        Admit to ICU / HCU for Care
# 16    84     B                             Admit to Ward for Care
# 17    27     B                        Admit to ICU / HCU for Care
# 19    58     B  Immediate Surgical intervention(then Ward / IC...
# 24    70     B                             Admit to Ward for Care
# 26    43     B                             Admit to Ward for Care
# ...
